# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from pprint import pprint 
import scipy
import seaborn as sns
import pandas as pd
import csv
import os

# %% [markdown]
# ## Files

# %%
spike_dataset = "S1U" # edit as necessary
r2_dir = '../Results/' # Where R2 results are stored
cycle_path = "../spikesByCycle/" # Where spikesByCycle results are stored

# %%
files = next(os.walk(r2_dir))[2]
files = [f for f in files if spike_dataset in f and 'Br' not in f]

# %% [markdown]
# ## Organize Data

# %%
dataset = ["RyCon", "RyNb", "YeCon", "YeNb"]
marker_regions = ['Anterior', 'Intermediate', 'Posterior', 'Superficial', 'Deep']
xyz = ['X', 'Y', 'Z']

# %%
raw_data = defaultdict(dict)
for f in files:
    curr_file = pd.read_csv(r2_dir + '/' + f)
    name = f.split('.')[0]

    column_names = list(curr_file.columns[1:])
    r2s = {cn.strip() : float(curr_file[cn].values) for cn in column_names}
    for d in dataset:
        if d in name:
            region = name.split('_')[2]
            raw_data[d][region] = r2s

# %%
def XYZ(markers):
    data = {
        'X': np.asarray([markers[i] for i in range(0, len(markers), 3)], dtype=float),
        'Y': np.asarray([markers[i + 1] for i in range(0, len(markers), 3)], dtype=float),
        'Z': np.asarray([markers[i + 2] for i in range(0, len(markers), 3)], dtype=float),
    }
    return data

def cat_XYZ(*args):
    data = {
        'X': np.concatenate(([arg['X'] for arg in args])).astype(float),
        'Y': np.concatenate(([arg['Y'] for arg in args])).astype(float),
        'Z': np.concatenate(([arg['Z'] for arg in args])).astype(float),
    }
    return data

region_xyz = defaultdict(dict)
for d in dataset:
    for mr in marker_regions:
        values = list(raw_data[d][mr].values())
        region_xyz[d][mr] = XYZ(values)

data_xyz = {}
for d in dataset:
    relevant = list(region_xyz[d].values())
    data_xyz[d] = cat_XYZ(*relevant)

# %% [markdown]
# ## Heat Map

# %%
def get_frame(regions, features, data):
    feature = []
    region = []
    values = []
    for r in regions:
        for i in range(3):
            region.append(r)
        feature.append(features[0])
        feature.append(features[1])
        feature.append(features[2])
    for d in data:
        values.append(np.mean(d['X']))
        values.append(np.mean(d['Y']))
        values.append(np.mean(d['Z']))
    dict = {
        'Axis': feature,
        'Region': region,
        'Values': values
    }

    return pd.DataFrame(dict)

# %%
def heatmap(frame_c, frame_nb, title):
    heatmap_c = frame_c.pivot(columns='Axis',index='Region', values='Values')
    heatmap_nb = frame_nb.pivot(columns='Axis',index='Region', values='Values')

    plt.figure(figsize=(8, 4))
    plt.suptitle(title)
    plt.subplot(1, 2, 1)
    plt.title('Control')
    sns.heatmap(heatmap_c, vmin = 0, vmax = 1, annot=True, cmap='inferno')
    plt.subplot(1, 2, 2)
    plt.title('Nerve Block')
    sns.heatmap(heatmap_nb, vmin = 0, vmax = 1, annot=True, cmap='inferno')
    plt.show()

# %%
frames = {}
region = ['A', 'I', 'P']
depth = ['S', 'D']

for d in dataset:
    frames[d + ' Region'] = get_frame(region, xyz, [region_xyz[d]['Anterior'], region_xyz[d]['Intermediate'], region_xyz[d]['Posterior']])
    frames[d + ' Depth'] = get_frame(depth, xyz, [region_xyz[d]['Superficial'], region_xyz[d]['Deep']])

heatmap(frames['RyCon Region'], frames['RyNb Region'], 'Monkey R')
heatmap(frames['RyCon Depth'], frames['RyNb Depth'], 'Monkey R')
heatmap(frames['YeCon Region'], frames['YeNb Region'], 'Monkey Y')
heatmap(frames['YeCon Depth'], frames['YeNb Depth'], 'Monkey Y')

# %% [markdown]
# ## Spike Histogram

# %%
cycles = ["ChewL", "ChewR", "Manipulation", "SwallowInterc", "SwallowTerm"]

def test_cycle(data, cycle):
    if data["cycleType"] != cycle.lower():
        print("Expected: ", cycle)
        print("Real: ", data["cycleType"])
    return

for d_i, d in enumerate(dataset):
    plt.figure(figsize=(15, 7))
    for c_i, c in enumerate(cycles):
        cycle_data = scipy.io.loadmat(cycle_path + d + "_" + c)
        test_cycle(cycle_data, c)
        
        input = None
        neurons = [str(s).split()[1] for s in cycle_data["snrs"][spike_dataset.lower()][0, 0]]
        num_neurons = len(neurons)
        for i, neuron in enumerate(neurons):
            neuron_spikes = cycle_data["spikesByGapeCycle"][spike_dataset.lower()][0, 0][neuron]
            for j in range(neuron_spikes.shape[1]):
                extracted = np.squeeze(neuron_spikes[0, j][0, 0][0], axis=1)
                input = extracted if i == 0 and j == 0 else np.concatenate((input, extracted))
        
        plt.subplot(2, 3, c_i + 1)
        plt.title(d + "_" + c)
        y, x = np.histogram(input, bins=30)
        plt.bar(x[:-1], y / (num_neurons * 20), width=0.03)
    plt.show()

# %% [markdown]
# ## Percent Decrease (Post-Nerve Block)

# %%
def avg_pctdec(c, nb):
    diff = np.subtract(c, nb)
    div = diff / c
    return np.mean(div) * 100

def plot_pctdec(rc, rnb, yc, ynb):
    colors = ['blue', 'orange', 'green']
    rocky = []
    yosemite = []
    for i in range(len(xyz)):
        rocky.append(avg_pctdec(rc[xyz[i]], rnb[xyz[i]]))
        yosemite.append(avg_pctdec(yc[xyz[i]], ynb[xyz[i]]))

    plt.figure()
    plt.subplot(1, 2, 1)
    plt.title('Monkey R')
    plt.ylabel('Average Decoding Performance Degradation')
    plt.ylim(0, 100)
    plt.bar(xyz, rocky, color=colors)

    plt.subplot(1, 2, 2)
    plt.title('Monkey Y')
    plt.ylim(0, 100)
    plt.bar(xyz, yosemite, color=colors)

# %%
plot_pctdec(*[data_xyz[d] for d in dataset])

# %% [markdown]
# ## Statistical Analysis

# %%
def print_stats(title, *datasets):
    if len(datasets) > 2:
        stat, p = scipy.stats.kruskal(*datasets)
    else:
        stat, p = scipy.stats.mannwhitneyu(*datasets)
    mult = ''
    if p < 0.05 and len(datasets) > 2:
        mult = scipy.stats.tukey_hsd(*datasets)
    elif p < 0.05:
        mult = 'Significant'

    print(title)
    print()
    print('H Statistic: ' + str(stat))
    print('P-Value: ' + str(p))
    if mult != '':
        print()
        print(mult)
    print()
    return float(stat)

# %% [markdown]
# ### Control vs. Nerve Block

# %%
for i in range(len(xyz)):
    print_stats('Rocky ' + xyz[i], data_xyz['RyCon'][xyz[i]], data_xyz['RyNb'][xyz[i]])

for i in range(len(xyz)):
    print_stats('Yosemite ' + xyz[i], data_xyz['YeCon'][xyz[i]], data_xyz['YeNb'][xyz[i]])
# Out:
# Rocky X
#
# H Statistic: 622.0
# P-Value: 2.028844528419201e-09
#
# Significant
#
# Rocky Y
#
# H Statistic: 624.0
# P-Value: 1.5966671856908888e-09
#
# Significant
#
# Rocky Z
#
# H Statistic: 536.0
# P-Value: 1.512668097157208e-05
#
# Significant
#
# Yosemite X
#
# H Statistic: 625.0
# P-Value: 1.4156562248495537e-09
#
# Significant
#
# Yosemite Y
#
# H Statistic: 625.0
# P-Value: 1.4156562248495537e-09
#
# Significant
#
# Yosemite Z
#
# H Statistic: 625.0
# P-Value: 1.4156562248495537e-09
#
# Significant

# %% [markdown]
# ### Across Regions

# %%
print('Anterior vs. Intermediate vs. Posterior')
print()
for d in dataset:
    print(d)
    print()
    for i in range(len(xyz)):
        print_stats(xyz[i], region_xyz[d]['Anterior'][xyz[i]], region_xyz[d]['Intermediate'][xyz[i]], region_xyz[d]['Posterior'][xyz[i]])
# Out:
# Anterior vs. Intermediate vs. Posterior
#
# RyCon
#
# X
#
# H Statistic: 2.7696428571428555
# P-Value: 0.2503685044616001
#
# Y
#
# H Statistic: 5.38214285714286
# P-Value: 0.06780824874222553
#
# Z
#
# H Statistic: 3.341071428571425
# P-Value: 0.1881462460041111
#
# RyNb
#
# X
#
# H Statistic: 8.426785714285714
# P-Value: 0.014796082086498494
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.020     0.043    -0.040    -0.001
#  (0 - 2)     -0.020     0.045    -0.040    -0.000
#  (1 - 0)      0.020     0.043     0.001     0.040
#  (1 - 2)      0.000     1.000    -0.022     0.022
#  (2 - 0)      0.020     0.045     0.000     0.040
#  (2 - 1)     -0.000     1.000    -0.022     0.022
#
#
# Y
#
# H Statistic: 5.028571428571425
# P-Value: 0.08092069206291491
#
# Z
#
# H Statistic: 3.25
# P-Value: 0.19691167520419406
#
# YeCon
#
# X
#
# H Statistic: 4.7071428571428555
# P-Value: 0.09502916556305024
#
# Y
#
# H Statistic: 4.926785714285714
# P-Value: 0.08514557356936471
#
# Z
#
# H Statistic: 0.01964285714285552
# P-Value: 0.9902266441485114
#
# YeNb
#
# X
#
# H Statistic: 3.426785714285714
# P-Value: 0.18025318066084078
#
# Y
#
# H Statistic: 0.841071428571432
# P-Value: 0.6566949247133299
#
# Z
#
# H Statistic: 3.50714285714286
# P-Value: 0.17315442915785584

# %%
print('Superficial vs. Deep')
print()
for d in dataset:
    print(d)
    print()
    for i in range(len(xyz)):
        print_stats(xyz[i], region_xyz[d]['Superficial'][xyz[i]], region_xyz[d]['Deep'][xyz[i]])
# Out:
# Superficial vs. Deep
#
# RyCon
#
# X
#
# H Statistic: 7.0
# P-Value: 0.35238095238095235
#
# Y
#
# H Statistic: 14.0
# P-Value: 0.7619047619047619
#
# Z
#
# H Statistic: 21.0
# P-Value: 0.06666666666666667
#
# RyNb
#
# X
#
# H Statistic: 5.0
# P-Value: 0.17142857142857143
#
# Y
#
# H Statistic: 17.0
# P-Value: 0.35238095238095235
#
# Z
#
# H Statistic: 7.0
# P-Value: 0.35238095238095235
#
# YeCon
#
# X
#
# H Statistic: 10.0
# P-Value: 0.7619047619047619
#
# Y
#
# H Statistic: 11.0
# P-Value: 0.9142857142857143
#
# Z
#
# H Statistic: 13.0
# P-Value: 0.9142857142857143
#
# YeNb
#
# X
#
# H Statistic: 23.0
# P-Value: 0.01904761904761905
#
# Significant
#
# Y
#
# H Statistic: 12.0
# P-Value: 1.0
#
# Z
#
# H Statistic: 20.0
# P-Value: 0.11428571428571428

# %% [markdown]
# ### Across Axes of Motion

# %%
print('X vs. Y vs. Z')
print()
for d in dataset:
    print(d)
    print()
    print_stats('Anterior', region_xyz[d]['Anterior']['X'], region_xyz[d]['Anterior']['Y'], region_xyz[d]['Anterior']['Z'])
    print_stats('Intermediate', region_xyz[d]['Intermediate']['X'], region_xyz[d]['Intermediate']['Y'], region_xyz[d]['Intermediate']['Z'])
    print_stats('Posterior', region_xyz[d]['Posterior']['X'], region_xyz[d]['Posterior']['Y'], region_xyz[d]['Posterior']['Z'])
# Out:
# X vs. Y vs. Z
#
# RyCon
#
# Anterior
#
# H Statistic: 14.092764378478662
# P-Value: 0.0008705527621832153
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.137     0.001    -0.213    -0.061
#  (0 - 2)      0.091     0.018     0.015     0.167
#  (1 - 0)      0.137     0.001     0.061     0.213
#  (1 - 2)      0.228     0.000     0.152     0.304
#  (2 - 0)     -0.091     0.018    -0.167    -0.015
#  (2 - 1)     -0.228     0.000    -0.304    -0.152
#
#
# Intermediate
#
# H Statistic: 3.5
# P-Value: 0.1737739434504451
#
# Posterior
#
# H Statistic: 6.61538461538462
# P-Value: 0.036600539154270834
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.047     0.710    -0.210     0.116
#  (0 - 2)      0.099     0.261    -0.064     0.261
#  (1 - 0)      0.047     0.710    -0.116     0.210
#  (1 - 2)      0.145     0.079    -0.017     0.308
#  (2 - 0)     -0.099     0.261    -0.261     0.064
#  (2 - 1)     -0.145     0.079    -0.308     0.017
#
#
# RyNb
#
# Anterior
#
# H Statistic: 16.48237476808906
# P-Value: 0.0002635711034563854
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.087     0.000    -0.102    -0.073
#  (0 - 2)      0.022     0.003     0.007     0.036
#  (1 - 0)      0.087     0.000     0.073     0.102
#  (1 - 2)      0.109     0.000     0.095     0.123
#  (2 - 0)     -0.022     0.003    -0.036    -0.007
#  (2 - 1)     -0.109     0.000    -0.123    -0.095
#
#
# Intermediate
#
# H Statistic: 6.5
# P-Value: 0.03877420783172202
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.047     0.072    -0.099     0.004
#  (0 - 2)      0.003     0.986    -0.049     0.055
#  (1 - 0)      0.047     0.072    -0.004     0.099
#  (1 - 2)      0.050     0.056    -0.001     0.102
#  (2 - 0)     -0.003     0.986    -0.055     0.049
#  (2 - 1)     -0.050     0.056    -0.102     0.001
#
#
# Posterior
#
# H Statistic: 8.769230769230774
# P-Value: 0.01246768247477528
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.061     0.002    -0.096    -0.026
#  (0 - 2)      0.027     0.129    -0.008     0.062
#  (1 - 0)      0.061     0.002     0.026     0.096
#  (1 - 2)      0.088     0.000     0.053     0.123
#  (2 - 0)     -0.027     0.129    -0.062     0.008
#  (2 - 1)     -0.088     0.000    -0.123    -0.053
#
#
# YeCon
#
# Anterior
#
# H Statistic: 14.923933209647501
# P-Value: 0.0005745251957392956
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.103     0.121    -0.229     0.023
#  (0 - 2)      0.230     0.001     0.104     0.356
#  (1 - 0)      0.103     0.121    -0.023     0.229
#  (1 - 2)      0.333     0.000     0.207     0.459
#  (2 - 0)     -0.230     0.001    -0.356    -0.104
#  (2 - 1)     -0.333     0.000    -0.459    -0.207
#
#
# Intermediate
#
# H Statistic: 7.423076923076927
# P-Value: 0.024439894496176142
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.026     0.741    -0.125     0.072
#  (0 - 2)      0.145     0.007     0.046     0.243
#  (1 - 0)      0.026     0.741    -0.072     0.125
#  (1 - 2)      0.171     0.002     0.073     0.269
#  (2 - 0)     -0.145     0.007    -0.243    -0.046
#  (2 - 1)     -0.171     0.002    -0.269    -0.073
#
#
# Posterior
#
# H Statistic: 7.384615384615387
# P-Value: 0.024914440787632705
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)      0.039     0.817    -0.140     0.219
#  (0 - 2)      0.294     0.003     0.115     0.474
#  (1 - 0)     -0.039     0.817    -0.219     0.140
#  (1 - 2)      0.255     0.008     0.075     0.435
#  (2 - 0)     -0.294     0.003    -0.474    -0.115
#  (2 - 1)     -0.255     0.008    -0.435    -0.075
#
#
# YeNb
#
# Anterior
#
# H Statistic: 13.410018552875712
# P-Value: 0.0012247613424717424
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.014     0.010    -0.024    -0.003
#  (0 - 2)      0.009     0.086    -0.001     0.020
#  (1 - 0)      0.014     0.010     0.003     0.024
#  (1 - 2)      0.023     0.000     0.012     0.033
#  (2 - 0)     -0.009     0.086    -0.020     0.001
#  (2 - 1)     -0.023     0.000    -0.033    -0.012
#
#
# Intermediate
#
# H Statistic: 3.1153846153846203
# P-Value: 0.21062156056041947
#
# Posterior
#
# H Statistic: 2.423076923076927
# P-Value: 0.29773886709989583

# %%
print('X vs. Y vs. Z')
print()
for d in dataset:
    print(d)
    print()
    print_stats('Superficial', region_xyz[d]['Superficial']['X'], region_xyz[d]['Superficial']['Y'], region_xyz[d]['Superficial']['Z'])
    print_stats('Deep', region_xyz[d]['Deep']['X'], region_xyz[d]['Deep']['Y'], region_xyz[d]['Deep']['Z'])
# Out:
# X vs. Y vs. Z
#
# RyCon
#
# Superficial
#
# H Statistic: 8.84210526315789
# P-Value: 0.012021571336618473
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.155     0.007    -0.268    -0.042
#  (0 - 2)     -0.091     0.124    -0.204     0.022
#  (1 - 0)      0.155     0.007     0.042     0.268
#  (1 - 2)      0.064     0.328    -0.049     0.177
#  (2 - 0)      0.091     0.124    -0.022     0.204
#  (2 - 1)     -0.064     0.328    -0.177     0.049
#
#
# Deep
#
# H Statistic: 8.769230769230774
# P-Value: 0.01246768247477528
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.117     0.005    -0.192    -0.042
#  (0 - 2)      0.026     0.621    -0.049     0.100
#  (1 - 0)      0.117     0.005     0.042     0.192
#  (1 - 2)      0.143     0.001     0.068     0.218
#  (2 - 0)     -0.026     0.621    -0.100     0.049
#  (2 - 1)     -0.143     0.001    -0.218    -0.068
#
#
# RyNb
#
# Superficial
#
# H Statistic: 11.590643274853804
# P-Value: 0.0030417519280741155
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.063     0.000    -0.096    -0.031
#  (0 - 2)      0.011     0.647    -0.021     0.044
#  (1 - 0)      0.063     0.000     0.031     0.096
#  (1 - 2)      0.074     0.000     0.042     0.107
#  (2 - 0)     -0.011     0.647    -0.044     0.021
#  (2 - 1)     -0.074     0.000    -0.107    -0.042
#
#
# Deep
#
# H Statistic: 8.0
# P-Value: 0.018315638888734182
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.041     0.006    -0.069    -0.014
#  (0 - 2)      0.009     0.617    -0.018     0.037
#  (1 - 0)      0.041     0.006     0.014     0.069
#  (1 - 2)      0.051     0.002     0.023     0.078
#  (2 - 0)     -0.009     0.617    -0.037     0.018
#  (2 - 1)     -0.051     0.002    -0.078    -0.023
#
#
# YeCon
#
# Superficial
#
# H Statistic: 9.274853801169584
# P-Value: 0.009682579842132926
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.034     0.763    -0.159     0.091
#  (0 - 2)      0.159     0.013     0.034     0.284
#  (1 - 0)      0.034     0.763    -0.091     0.159
#  (1 - 2)      0.193     0.003     0.068     0.318
#  (2 - 0)     -0.159     0.013    -0.284    -0.034
#  (2 - 1)     -0.193     0.003    -0.318    -0.068
#
#
# Deep
#
# H Statistic: 7.53846153846154
# P-Value: 0.0230698024654865
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.039     0.712    -0.174     0.097
#  (0 - 2)      0.173     0.015     0.037     0.308
#  (1 - 0)      0.039     0.712    -0.097     0.174
#  (1 - 2)      0.211     0.005     0.076     0.347
#  (2 - 0)     -0.173     0.015    -0.308    -0.037
#  (2 - 1)     -0.211     0.005    -0.347    -0.076
#
#
# YeNb
#
# Superficial
#
# H Statistic: 9.69590643274853
# P-Value: 0.007844416953204793
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.002     0.935    -0.016     0.012
#  (0 - 2)      0.017     0.021     0.002     0.031
#  (1 - 0)      0.002     0.935    -0.012     0.016
#  (1 - 2)      0.018     0.010     0.004     0.033
#  (2 - 0)     -0.017     0.021    -0.031    -0.002
#  (2 - 1)     -0.018     0.010    -0.033    -0.004
#
#
# Deep
#
# H Statistic: 6.269230769230774
# P-Value: 0.043516487721702336
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.013     0.190    -0.032     0.006
#  (0 - 2)      0.007     0.613    -0.013     0.026
#  (1 - 0)      0.013     0.190    -0.006     0.032
#  (1 - 2)      0.020     0.043     0.001     0.039
#  (2 - 0)     -0.007     0.613    -0.026     0.013
#  (2 - 1)     -0.020     0.043    -0.039    -0.001
