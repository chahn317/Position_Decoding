# %% [markdown]
# ## Install Required Packages

# %%
# %%bash
# python3.11 -m pip install --upgrade pip
# pip install numpy
# pip install scipy
# pip install keras
# pip install tensorflow
# pip install pandas
# Out:
# Requirement already satisfied: pip in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (24.3.1)
# Requirement already satisfied: numpy in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (1.23.5)
# Requirement already satisfied: scipy in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (1.10.0)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from scipy) (1.23.5)
# Requirement already satisfied: keras in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: tensorflow in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (0.4.24)
# Requirement already satisfied: libclang>=13.0.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (1.48.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (2.12.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.35.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow) (0.3.2)
# Requirement already satisfied: scipy>=1.9 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow) (1.10.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Requirement already satisfied: pandas in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/christinahahn/anaconda3/envs/neural/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ## Imports

# %%
import numpy as np
from scipy import io
import os
import pickle
import pandas as pd

# Import function to get covariate matrix that includes spike history from previous bins
from Neural_Decoding.preprocessing_funcs import get_spikes_with_history

# Import metrics
from Neural_Decoding.metrics import get_R2
from Neural_Decoding.metrics import get_rho

# Import decoder functions
from Neural_Decoding.decoders import LSTMDecoder

# %% [markdown]
# ## User Inputs (Modify as Necessary)

# %%
binned_dir = "Data_Binned" # Name of directory that stores binned results
results_dir = "Results" # Name of directory that will store results

bins_before = 5 # How many bins of neural data prior to the output are used for decoding (fewer bins is faster)
bins_current = 1 # Whether to use concurrent time bin of neural data
bins_after = 5 # How many bins of neural data after the output are used for decoding (fewer bins is faster)

training_range = [0, 0.85] # Range of training data
testing_range = [0.85, 1] # Range of testing data

# %% [markdown]
# ## LSTM

# %%
# Get all .pickle files
parent_dir = os.path.dirname(os.path.abspath("__file__"))
data_dir = os.path.join(parent_dir, binned_dir)
files = next(os.walk(data_dir))[2]

results_dir = os.path.join(parent_dir, results_dir)
if not os.path.exists(results_dir):
    os.mkdir(results_dir)

for f in files:
    if not '.pickle' in f:
        continue

    dataset = f.split('.')[0]
    print('dataset: ' + dataset)

    # Skip dataset if results already exist
    if os.path.exists(results_dir + '/' + dataset + '.csv'):
        continue

    with open(data_dir + "/" + f, 'rb') as res:
        neural_data, pos_binned, markers = pickle.load(res, encoding='latin1')

    X = get_spikes_with_history(neural_data, bins_before, bins_after, bins_current)
    y = pos_binned

    num_examples = X.shape[0]
    training_set = np.arange(int(np.round(training_range[0] * num_examples)) + bins_before, int(np.round(training_range[1] * num_examples)) - bins_after)
    testing_set = np.arange(int(np.round(testing_range[0] * num_examples)) + bins_before, int(np.round(testing_range[1] * num_examples)) - bins_after)

    # Get training data
    X_train = X[training_set, :, :]
    y_train = y[training_set, :]

    # Get testing data
    X_test = X[testing_set, :, :]
    y_test = y[testing_set, :]

    # Z-score "X" inputs. 
    X_train_mean = np.nanmean(X_train, axis=0)
    X_train_std = np.nanstd(X_train, axis=0)
    X_train = np.divide((X_train - X_train_mean), X_train_std, where=X_train_std[1] != 0)
    X_test = np.divide((X_test - X_train_mean), X_train_std, where=X_train_std[1] != 0)


    # Zero-center outputs
    y_train_mean = np.nanmean(y_train, axis=0)
    y_train = y_train - y_train_mean
    y_test = y_test - y_train_mean

    # Declare model
    model_lstm = LSTMDecoder(units=400, dropout=0, num_epochs=20, verbose=1)

    # Fit model
    model_lstm.fit(X_train, y_train)

    # Get predictions
    y_predicted_lstm = model_lstm.predict(X_test)

    # Get results
    R2_lstm = get_rho(y_test, y_predicted_lstm) ** 2
    print('R2:', R2_lstm)
    markers = [m[0][0].replace('30Hz_', '') for m in markers]
    print(markers)

    results = {label: r2 for label, r2 in zip(markers, R2_lstm)}
    df = pd.DataFrame(results, index = [0])
    df.to_csv(results_dir + '/' + dataset + '.csv')
# Out:
# dataset: Br_S1U_Superficial
# dataset: Br_PFU_Superficial
# dataset: YeCon_M1U_Anterior
# dataset: Br_CSF_Superficial
# dataset: RyCon_S1F_Deep
# dataset: YeNb_M1F_Posterior
# dataset: YeCon_S1U_Anterior
# dataset: RyCon_M1F_Posterior
# dataset: YeCon_S1U_Deep
# dataset: RyCon_S1U_Intermediate
# dataset: RyCon_S1U_Deep
# dataset: Br_CSF_Intermediate
# dataset: Br_S1U_Deep
# dataset: Br_S1U_Posterior
# dataset: YeCon_S1U_Posterior
# dataset: RyNb_M1U_Posterior
# Epoch 1/20
# 401/401 [==============================] - 15s 34ms/step - loss: 14.2211 - accuracy: 0.5291
# Epoch 2/20
# 401/401 [==============================] - 15s 38ms/step - loss: 4.2215 - accuracy: 0.6302
# Epoch 3/20
# 401/401 [==============================] - 15s 37ms/step - loss: 2.1020 - accuracy: 0.6879
# Epoch 4/20
# 401/401 [==============================] - 15s 38ms/step - loss: 1.2083 - accuracy: 0.7294
# Epoch 5/20
# 401/401 [==============================] - 15s 37ms/step - loss: 1.0549 - accuracy: 0.7533
# Epoch 6/20
# 401/401 [==============================] - 15s 37ms/step - loss: 0.7532 - accuracy: 0.7770
# Epoch 7/20
# 401/401 [==============================] - 15s 37ms/step - loss: 0.5545 - accuracy: 0.7913
# Epoch 8/20
# 401/401 [==============================] - 16s 39ms/step - loss: 0.5168 - accuracy: 0.8110
# Epoch 9/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.4404 - accuracy: 0.8235
# Epoch 10/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.4973 - accuracy: 0.8326
# Epoch 11/20
# 401/401 [==============================] - 15s 39ms/step - loss: 0.3325 - accuracy: 0.8299
# Epoch 12/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.3066 - accuracy: 0.8359
# Epoch 13/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.2475 - accuracy: 0.8513
# Epoch 14/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.2831 - accuracy: 0.8558
# Epoch 15/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.2051 - accuracy: 0.8633
# Epoch 16/20
# 401/401 [==============================] - 18s 45ms/step - loss: 0.1961 - accuracy: 0.8691
# Epoch 17/20
# 401/401 [==============================] - 16s 39ms/step - loss: 0.1786 - accuracy: 0.8694
# Epoch 18/20
# 401/401 [==============================] - 19s 48ms/step - loss: 0.2094 - accuracy: 0.8802
# Epoch 19/20
# 401/401 [==============================] - 17s 43ms/step - loss: 0.1558 - accuracy: 0.8820
# Epoch 20/20
# 401/401 [==============================] - 15s 37ms/step - loss: 0.1425 - accuracy: 0.8774
# 71/71 [==============================] - 1s 9ms/step
# R2: [0.21129648 0.76931109 0.03639346 0.18410144 0.77031494 0.14487474
#  0.65774906 0.71232914 0.75308175 0.61145882 0.70869679 0.7021145 ]
# [' PosteriorMandibleR_X ', ' PosteriorMandibleR_Y ', ' PosteriorMandibleR_Z ', ' PosteriorMandibleL_X ', ' PosteriorMandibleL_Y ', ' PosteriorMandibleL_Z ', ' PosteriorSuperficialM_X ', ' PosteriorSuperficialM_Y ', ' PosteriorSuperficialM_Z ', ' PosteriorDeepM_X ', ' PosteriorDeepM_Y ', ' PosteriorDeepM_Z ']
# dataset: YeNb_S1U_Anterior
# dataset: Br_M1U_Superficial
# dataset: RyCon_S1F_Intermediate
# dataset: YeNb_M1U_Anterior
# dataset: YeCon_S1F_Deep
# dataset: YeNb_S1U_Posterior
# dataset: YeNb_S1U_Deep
# dataset: YeNb_S1F_Superficial
# dataset: RyNb_S1U_Intermediate
# Epoch 1/20
# 401/401 [==============================] - 15s 35ms/step - loss: 38.2309 - accuracy: 0.1977
# Epoch 2/20
# 401/401 [==============================] - 15s 39ms/step - loss: 35.7683 - accuracy: 0.2411
# Epoch 3/20
# 401/401 [==============================] - 15s 38ms/step - loss: 32.2616 - accuracy: 0.2657
# Epoch 4/20
# 401/401 [==============================] - 15s 37ms/step - loss: 27.1498 - accuracy: 0.2804
# Epoch 5/20
# 401/401 [==============================] - 21s 53ms/step - loss: 23.1342 - accuracy: 0.2965
# Epoch 6/20
# 401/401 [==============================] - 14s 35ms/step - loss: 20.3216 - accuracy: 0.3231
# Epoch 7/20
# 401/401 [==============================] - 14s 35ms/step - loss: 17.4437 - accuracy: 0.3410
# Epoch 8/20
# 401/401 [==============================] - 14s 35ms/step - loss: 15.3949 - accuracy: 0.3626
# Epoch 9/20
# 401/401 [==============================] - 15s 37ms/step - loss: 13.1900 - accuracy: 0.3918
# Epoch 10/20
# 401/401 [==============================] - 17s 43ms/step - loss: 11.5361 - accuracy: 0.4160
# Epoch 11/20
# 401/401 [==============================] - 14s 36ms/step - loss: 9.7363 - accuracy: 0.4444
# Epoch 12/20
# 401/401 [==============================] - 14s 35ms/step - loss: 8.2001 - accuracy: 0.4739
# Epoch 13/20
# 401/401 [==============================] - 18s 44ms/step - loss: 6.9845 - accuracy: 0.4965
# Epoch 14/20
# 401/401 [==============================] - 14s 34ms/step - loss: 5.9015 - accuracy: 0.5241
# Epoch 15/20
# 401/401 [==============================] - 19s 47ms/step - loss: 5.0748 - accuracy: 0.5438
# Epoch 16/20
# 401/401 [==============================] - 21s 53ms/step - loss: 4.4721 - accuracy: 0.5667
# Epoch 17/20
# 401/401 [==============================] - 16s 40ms/step - loss: 3.7868 - accuracy: 0.5910
# Epoch 18/20
# 401/401 [==============================] - 17s 43ms/step - loss: 3.4074 - accuracy: 0.6000
# Epoch 19/20
# 401/401 [==============================] - 19s 47ms/step - loss: 3.0106 - accuracy: 0.6113
# Epoch 20/20
# 401/401 [==============================] - 19s 46ms/step - loss: 2.7157 - accuracy: 0.6315
# 71/71 [==============================] - 1s 7ms/step
# R2: [0.04953869 0.10823538 0.00203318 0.04991473 0.1050183  0.02742667
#  0.05537527 0.07311118 0.09882087 0.04760893 0.10561259 0.06218164]
# [' IntermediateSuperficialR_X ', ' IntermediateSuperficialR_Y ', ' IntermediateSuperficialR_Z ', ' IntermediateSuperficialM_X ', ' IntermediateSuperficialM_Y ', ' IntermediateSuperficialM_Z ', ' IntermediateSuperficialL_X ', ' IntermediateSuperficialL_Y ', ' IntermediateSuperficialL_Z ', ' IntermediateDeepM_X ', ' IntermediateDeepM_Y ', ' IntermediateDeepM_Z ']
# dataset: YeNb_S1F_Intermediate
# dataset: YeCon_S1F_Superficial
# dataset: RyNb_M1U_Superficial
# Epoch 1/20
# 401/401 [==============================] - 21s 50ms/step - loss: 25.8975 - accuracy: 0.4576
# Epoch 2/20
# 401/401 [==============================] - 17s 43ms/step - loss: 7.6832 - accuracy: 0.5724
# Epoch 3/20
# 401/401 [==============================] - 16s 39ms/step - loss: 4.2170 - accuracy: 0.6189
# Epoch 4/20
# 401/401 [==============================] - 20s 49ms/step - loss: 3.1777 - accuracy: 0.6647
# Epoch 5/20
# 401/401 [==============================] - 20s 49ms/step - loss: 2.6291 - accuracy: 0.6966
# Epoch 6/20
# 401/401 [==============================] - 19s 47ms/step - loss: 1.8101 - accuracy: 0.7194
# Epoch 7/20
# 401/401 [==============================] - 20s 49ms/step - loss: 1.4654 - accuracy: 0.7360
# Epoch 8/20
# 401/401 [==============================] - 15s 38ms/step - loss: 1.1660 - accuracy: 0.7514
# Epoch 9/20
# 401/401 [==============================] - 19s 47ms/step - loss: 1.0173 - accuracy: 0.7647
# Epoch 10/20
# 401/401 [==============================] - 20s 51ms/step - loss: 0.9302 - accuracy: 0.7721
# Epoch 11/20
# 401/401 [==============================] - 18s 44ms/step - loss: 0.9734 - accuracy: 0.7886
# Epoch 12/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.7716 - accuracy: 0.7920
# Epoch 13/20
# 401/401 [==============================] - 13s 33ms/step - loss: 0.6934 - accuracy: 0.7986
# Epoch 14/20
# 401/401 [==============================] - 19s 46ms/step - loss: 0.6743 - accuracy: 0.8080
# Epoch 15/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.6282 - accuracy: 0.8097
# Epoch 16/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.5428 - accuracy: 0.8168
# Epoch 17/20
# 401/401 [==============================] - 18s 45ms/step - loss: 0.5183 - accuracy: 0.8214
# Epoch 18/20
# 401/401 [==============================] - 16s 39ms/step - loss: 0.4829 - accuracy: 0.8242
# Epoch 19/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.4541 - accuracy: 0.8280
# Epoch 20/20
# 401/401 [==============================] - 20s 50ms/step - loss: 0.4378 - accuracy: 0.8322
# 71/71 [==============================] - 1s 9ms/step
# R2: [0.31938315 0.79955481 0.3937138  0.26905724 0.76259194 0.44413722
#  0.39876633 0.75927116 0.26604772 0.36347516 0.77935588 0.79276038
#  0.45313645 0.68388859 0.77029485 0.65093889 0.67215342 0.70889246]
# [' AnteriorSuperficialR_X ', ' AnteriorSuperficialR_Y ', ' AnteriorSuperficialR_Z ', ' AnteriorSuperficialL_X ', ' AnteriorSuperficialL_Y ', ' AnteriorSuperficialL_Z ', ' IntermediateSuperficialR_X ', ' IntermediateSuperficialR_Y ', ' IntermediateSuperficialR_Z ', ' IntermediateSuperficialM_X ', ' IntermediateSuperficialM_Y ', ' IntermediateSuperficialM_Z ', ' IntermediateSuperficialL_X ', ' IntermediateSuperficialL_Y ', ' IntermediateSuperficialL_Z ', ' PosteriorSuperficialM_X ', ' PosteriorSuperficialM_Y ', ' PosteriorSuperficialM_Z ']
# dataset: YeNb_S1U_Intermediate
# dataset: Br_PFU_Anterior
# dataset: RyNb_S1F_Deep
# Epoch 1/20
# 401/401 [==============================] - 16s 36ms/step - loss: 39.8778 - accuracy: 0.1603
# Epoch 2/20
# 401/401 [==============================] - 16s 41ms/step - loss: 39.7975 - accuracy: 0.1673
# Epoch 3/20
# 401/401 [==============================] - 17s 42ms/step - loss: 39.7462 - accuracy: 0.1676
# Epoch 4/20
# 401/401 [==============================] - 14s 36ms/step - loss: 39.7035 - accuracy: 0.1655
# Epoch 5/20
# 401/401 [==============================] - 19s 48ms/step - loss: 39.6599 - accuracy: 0.1628
# Epoch 6/20
# 401/401 [==============================] - 19s 48ms/step - loss: 39.6476 - accuracy: 0.1656
# Epoch 7/20
# 401/401 [==============================] - 18s 45ms/step - loss: 39.6356 - accuracy: 0.1701
# Epoch 8/20
# 401/401 [==============================] - 16s 39ms/step - loss: 39.5742 - accuracy: 0.1611
# Epoch 9/20
# 401/401 [==============================] - 15s 38ms/step - loss: 39.5344 - accuracy: 0.1665
# Epoch 10/20
# 401/401 [==============================] - 15s 38ms/step - loss: 39.5509 - accuracy: 0.1636
# Epoch 11/20
# 401/401 [==============================] - 14s 35ms/step - loss: 39.5159 - accuracy: 0.1683
# Epoch 12/20
# 401/401 [==============================] - 14s 36ms/step - loss: 39.4873 - accuracy: 0.1684
# Epoch 13/20
# 401/401 [==============================] - 12s 30ms/step - loss: 39.4808 - accuracy: 0.1712
# Epoch 14/20
# 401/401 [==============================] - 16s 40ms/step - loss: 39.4264 - accuracy: 0.1731
# Epoch 15/20
# 401/401 [==============================] - 15s 36ms/step - loss: 39.3817 - accuracy: 0.1683
# Epoch 16/20
# 401/401 [==============================] - 18s 44ms/step - loss: 39.3481 - accuracy: 0.1743
# Epoch 17/20
# 401/401 [==============================] - 16s 39ms/step - loss: 39.2590 - accuracy: 0.1745
# Epoch 18/20
# 401/401 [==============================] - 16s 40ms/step - loss: 39.1024 - accuracy: 0.1770
# Epoch 19/20
# 401/401 [==============================] - 18s 44ms/step - loss: 39.0128 - accuracy: 0.1789
# Epoch 20/20
# 401/401 [==============================] - 17s 41ms/step - loss: 38.8593 - accuracy: 0.1813
# 71/71 [==============================] - 1s 9ms/step
# R2: [1.33888482e-03 3.65171886e-03 1.80290334e-03 2.39567196e-03
#  1.16553221e-02 4.59650974e-04 7.24438279e-03 1.27071799e-02
#  1.51457666e-05 1.02481437e-02 4.89191841e-03 9.23528537e-03]
# [' AnteriorDeepR_X ', ' AnteriorDeepR_Y ', ' AnteriorDeepR_Z ', ' AnteriorDeepL_X ', ' AnteriorDeepL_Y ', ' AnteriorDeepL_Z ', ' IntermediateDeepM_X ', ' IntermediateDeepM_Y ', ' IntermediateDeepM_Z ', ' PosteriorDeepM_X ', ' PosteriorDeepM_Y ', ' PosteriorDeepM_Z ']
# dataset: YeCon_M1F_Anterior
# dataset: RyCon_S1F_Superficial
# dataset: RyCon_S1U_Posterior
# dataset: YeCon_S1F_Anterior
# dataset: RyNb_S1F_Intermediate
# Epoch 1/20
# 401/401 [==============================] - 22s 51ms/step - loss: 39.9726 - accuracy: 0.1723
# Epoch 2/20
# 401/401 [==============================] - 15s 37ms/step - loss: 39.8031 - accuracy: 0.1689
# Epoch 3/20
# 401/401 [==============================] - 16s 40ms/step - loss: 39.7727 - accuracy: 0.1722
# Epoch 4/20
# 401/401 [==============================] - 15s 38ms/step - loss: 39.7203 - accuracy: 0.1722
# Epoch 5/20
# 401/401 [==============================] - 14s 34ms/step - loss: 39.7091 - accuracy: 0.1664
# Epoch 6/20
# 401/401 [==============================] - 14s 34ms/step - loss: 39.6724 - accuracy: 0.1696
# Epoch 7/20
# 401/401 [==============================] - 20s 49ms/step - loss: 39.6272 - accuracy: 0.1732
# Epoch 8/20
# 401/401 [==============================] - 16s 39ms/step - loss: 39.6142 - accuracy: 0.1717
# Epoch 9/20
# 401/401 [==============================] - 18s 44ms/step - loss: 39.5706 - accuracy: 0.1757
# Epoch 10/20
# 401/401 [==============================] - 16s 41ms/step - loss: 39.5125 - accuracy: 0.1757
# Epoch 11/20
# 401/401 [==============================] - 13s 33ms/step - loss: 39.4706 - accuracy: 0.1780
# Epoch 12/20
# 401/401 [==============================] - 14s 35ms/step - loss: 39.4411 - accuracy: 0.1797
# Epoch 13/20
# 401/401 [==============================] - 27s 67ms/step - loss: 39.3578 - accuracy: 0.1768
# Epoch 14/20
# 401/401 [==============================] - 20s 49ms/step - loss: 39.2672 - accuracy: 0.1774
# Epoch 15/20
# 401/401 [==============================] - 14s 35ms/step - loss: 39.1676 - accuracy: 0.1837
# Epoch 16/20
# 401/401 [==============================] - 14s 34ms/step - loss: 39.0184 - accuracy: 0.1884
# Epoch 17/20
# 401/401 [==============================] - 15s 37ms/step - loss: 38.8593 - accuracy: 0.1936
# Epoch 18/20
# 401/401 [==============================] - 13s 31ms/step - loss: 38.6591 - accuracy: 0.2027
# Epoch 19/20
# 401/401 [==============================] - 13s 33ms/step - loss: 38.3385 - accuracy: 0.2005
# Epoch 20/20
# 401/401 [==============================] - 14s 34ms/step - loss: 38.1578 - accuracy: 0.1994
# 71/71 [==============================] - 1s 15ms/step
# R2: [1.75317720e-03 3.77711729e-03 4.39436415e-03 1.72934862e-03
#  8.19859413e-03 4.49803648e-06 4.84664847e-03 1.04719094e-02
#  4.53645795e-04 1.71409995e-03 8.73671960e-03 7.30205964e-04]
# [' IntermediateSuperficialR_X ', ' IntermediateSuperficialR_Y ', ' IntermediateSuperficialR_Z ', ' IntermediateSuperficialM_X ', ' IntermediateSuperficialM_Y ', ' IntermediateSuperficialM_Z ', ' IntermediateSuperficialL_X ', ' IntermediateSuperficialL_Y ', ' IntermediateSuperficialL_Z ', ' IntermediateDeepM_X ', ' IntermediateDeepM_Y ', ' IntermediateDeepM_Z ']
# dataset: RyCon_M1F_Superficial
# dataset: YeCon_S1F_Intermediate
# dataset: YeNb_S1F_Anterior
# dataset: Br_PFU_Intermediate
# dataset: YeCon_M1F_Posterior
# dataset: RyNb_S1U_Superficial
# Epoch 1/20
# 401/401 [==============================] - 18s 41ms/step - loss: 46.5235 - accuracy: 0.1609
# Epoch 2/20
# 401/401 [==============================] - 16s 40ms/step - loss: 43.5621 - accuracy: 0.2068
# Epoch 3/20
# 401/401 [==============================] - 18s 44ms/step - loss: 39.2145 - accuracy: 0.2298
# Epoch 4/20
# 401/401 [==============================] - 16s 41ms/step - loss: 33.8269 - accuracy: 0.2520
# Epoch 5/20
# 401/401 [==============================] - 17s 43ms/step - loss: 28.0884 - accuracy: 0.2590
# Epoch 6/20
# 401/401 [==============================] - 14s 36ms/step - loss: 24.0485 - accuracy: 0.2783
# Epoch 7/20
# 401/401 [==============================] - 17s 43ms/step - loss: 20.6587 - accuracy: 0.2923
# Epoch 8/20
# 401/401 [==============================] - 13s 33ms/step - loss: 18.6338 - accuracy: 0.3090
# Epoch 9/20
# 401/401 [==============================] - 13s 32ms/step - loss: 15.8320 - accuracy: 0.3354
# Epoch 10/20
# 401/401 [==============================] - 13s 33ms/step - loss: 13.7918 - accuracy: 0.3542
# Epoch 11/20
# 401/401 [==============================] - 16s 40ms/step - loss: 11.6930 - accuracy: 0.3891
# Epoch 12/20
# 401/401 [==============================] - 13s 32ms/step - loss: 9.9741 - accuracy: 0.4038
# Epoch 13/20
# 401/401 [==============================] - 14s 34ms/step - loss: 8.4837 - accuracy: 0.4361
# Epoch 14/20
# 401/401 [==============================] - 13s 33ms/step - loss: 7.4577 - accuracy: 0.4569
# Epoch 15/20
# 401/401 [==============================] - 15s 37ms/step - loss: 6.4952 - accuracy: 0.4783
# Epoch 16/20
# 401/401 [==============================] - 15s 39ms/step - loss: 5.5170 - accuracy: 0.5039
# Epoch 17/20
# 401/401 [==============================] - 13s 33ms/step - loss: 4.8481 - accuracy: 0.5191
# Epoch 18/20
# 401/401 [==============================] - 14s 35ms/step - loss: 4.3320 - accuracy: 0.5416
# Epoch 19/20
# 401/401 [==============================] - 13s 32ms/step - loss: 3.8873 - accuracy: 0.5533
# Epoch 20/20
# 401/401 [==============================] - 13s 32ms/step - loss: 3.5866 - accuracy: 0.5704
# 71/71 [==============================] - 1s 8ms/step
# R2: [0.02983568 0.13202012 0.00968932 0.02507752 0.11358701 0.02535418
#  0.03558544 0.10688951 0.00524067 0.03846155 0.10636612 0.01911147
#  0.04397273 0.07425089 0.08172283 0.06721024 0.08617142 0.03134451]
# [' AnteriorSuperficialR_X ', ' AnteriorSuperficialR_Y ', ' AnteriorSuperficialR_Z ', ' AnteriorSuperficialL_X ', ' AnteriorSuperficialL_Y ', ' AnteriorSuperficialL_Z ', ' IntermediateSuperficialR_X ', ' IntermediateSuperficialR_Y ', ' IntermediateSuperficialR_Z ', ' IntermediateSuperficialM_X ', ' IntermediateSuperficialM_Y ', ' IntermediateSuperficialM_Z ', ' IntermediateSuperficialL_X ', ' IntermediateSuperficialL_Y ', ' IntermediateSuperficialL_Z ', ' PosteriorSuperficialM_X ', ' PosteriorSuperficialM_Y ', ' PosteriorSuperficialM_Z ']
# dataset: Br_PFU_Deep
# dataset: YeNb_S1F_Deep
# dataset: Br_CSF_Posterior
# dataset: YeNb_M1F_Anterior
# dataset: Br_S1U_Intermediate
# dataset: Br_M1U_Anterior
# dataset: YeCon_M1F_Superficial
# dataset: RyNb_S1U_Deep
# Epoch 1/20
# 401/401 [==============================] - 16s 36ms/step - loss: 37.9845 - accuracy: 0.2149
# Epoch 2/20
# 401/401 [==============================] - 13s 33ms/step - loss: 35.5843 - accuracy: 0.2496
# Epoch 3/20
# 401/401 [==============================] - 18s 45ms/step - loss: 31.9162 - accuracy: 0.2785
# Epoch 4/20
# 401/401 [==============================] - 19s 46ms/step - loss: 26.7755 - accuracy: 0.2919
# Epoch 5/20
# 401/401 [==============================] - 18s 45ms/step - loss: 22.0339 - accuracy: 0.2984
# Epoch 6/20
# 401/401 [==============================] - 14s 35ms/step - loss: 19.6178 - accuracy: 0.3136
# Epoch 7/20
# 401/401 [==============================] - 15s 37ms/step - loss: 16.9734 - accuracy: 0.3286
# Epoch 8/20
# 401/401 [==============================] - 13s 32ms/step - loss: 14.7759 - accuracy: 0.3438
# Epoch 9/20
# 401/401 [==============================] - 16s 41ms/step - loss: 12.8905 - accuracy: 0.3636
# Epoch 10/20
# 401/401 [==============================] - 14s 36ms/step - loss: 10.9529 - accuracy: 0.3848
# Epoch 11/20
# 401/401 [==============================] - 14s 36ms/step - loss: 9.4450 - accuracy: 0.4064
# Epoch 12/20
# 401/401 [==============================] - 19s 47ms/step - loss: 7.9986 - accuracy: 0.4278
# Epoch 13/20
# 401/401 [==============================] - 17s 43ms/step - loss: 6.7963 - accuracy: 0.4460
# Epoch 14/20
# 401/401 [==============================] - 15s 38ms/step - loss: 5.8123 - accuracy: 0.4673
# Epoch 15/20
# 401/401 [==============================] - 15s 37ms/step - loss: 5.0387 - accuracy: 0.4842
# Epoch 16/20
# 401/401 [==============================] - 15s 39ms/step - loss: 4.4437 - accuracy: 0.5093
# Epoch 17/20
# 401/401 [==============================] - 15s 38ms/step - loss: 3.8220 - accuracy: 0.5286
# Epoch 18/20
# 401/401 [==============================] - 16s 40ms/step - loss: 3.5661 - accuracy: 0.5433
# Epoch 19/20
# 401/401 [==============================] - 17s 44ms/step - loss: 3.2104 - accuracy: 0.5551
# Epoch 20/20
# 401/401 [==============================] - 19s 48ms/step - loss: 2.8562 - accuracy: 0.5653
# 71/71 [==============================] - 1s 14ms/step
# R2: [0.05103121 0.10468775 0.02444662 0.04963696 0.09546327 0.04151369
#  0.04385149 0.08709575 0.07010757 0.05747683 0.07920137 0.02799461]
# [' AnteriorDeepR_X ', ' AnteriorDeepR_Y ', ' AnteriorDeepR_Z ', ' AnteriorDeepL_X ', ' AnteriorDeepL_Y ', ' AnteriorDeepL_Z ', ' IntermediateDeepM_X ', ' IntermediateDeepM_Y ', ' IntermediateDeepM_Z ', ' PosteriorDeepM_X ', ' PosteriorDeepM_Y ', ' PosteriorDeepM_Z ']
# dataset: Br_S1U_Anterior
# dataset: YeCon_S1U_Intermediate
# dataset: RyNb_S1F_Posterior
# Epoch 1/20
# 401/401 [==============================] - 16s 38ms/step - loss: 28.8899 - accuracy: 0.2566
# Epoch 2/20
# 401/401 [==============================] - 13s 32ms/step - loss: 28.6796 - accuracy: 0.2649
# Epoch 3/20
# 401/401 [==============================] - 20s 49ms/step - loss: 28.6447 - accuracy: 0.2623
# Epoch 4/20
# 401/401 [==============================] - 18s 46ms/step - loss: 28.6154 - accuracy: 0.2601
# Epoch 5/20
# 401/401 [==============================] - 13s 33ms/step - loss: 28.5914 - accuracy: 0.2605
# Epoch 6/20
# 401/401 [==============================] - 20s 49ms/step - loss: 28.5620 - accuracy: 0.2607
# Epoch 7/20
# 401/401 [==============================] - 19s 48ms/step - loss: 28.5310 - accuracy: 0.2585
# Epoch 8/20
# 401/401 [==============================] - 20s 51ms/step - loss: 28.4757 - accuracy: 0.2580
# Epoch 9/20
# 401/401 [==============================] - 13s 33ms/step - loss: 28.4870 - accuracy: 0.2606
# Epoch 10/20
# 401/401 [==============================] - 13s 33ms/step - loss: 28.4144 - accuracy: 0.2587
# Epoch 11/20
# 401/401 [==============================] - 16s 41ms/step - loss: 28.3637 - accuracy: 0.2574
# Epoch 12/20
# 401/401 [==============================] - 13s 32ms/step - loss: 28.3228 - accuracy: 0.2577
# Epoch 13/20
# 401/401 [==============================] - 12s 31ms/step - loss: 28.2338 - accuracy: 0.2519
# Epoch 14/20
# 401/401 [==============================] - 18s 44ms/step - loss: 28.1309 - accuracy: 0.2559
# Epoch 15/20
# 401/401 [==============================] - 16s 40ms/step - loss: 27.9882 - accuracy: 0.2503
# Epoch 16/20
# 401/401 [==============================] - 18s 45ms/step - loss: 27.6748 - accuracy: 0.2483
# Epoch 17/20
# 401/401 [==============================] - 17s 44ms/step - loss: 27.4824 - accuracy: 0.2534
# Epoch 18/20
# 401/401 [==============================] - 15s 38ms/step - loss: 27.0498 - accuracy: 0.2522
# Epoch 19/20
# 401/401 [==============================] - 16s 41ms/step - loss: 26.8046 - accuracy: 0.2598
# Epoch 20/20
# 401/401 [==============================] - 16s 40ms/step - loss: 26.5374 - accuracy: 0.2556
# 71/71 [==============================] - 1s 6ms/step
# R2: [0.00041822 0.00126162 0.00235416 0.00055188 0.00105953 0.00268509
#  0.00678774 0.00484095 0.00207264 0.00620833 0.00644316 0.00296002]
# [' PosteriorMandibleR_X ', ' PosteriorMandibleR_Y ', ' PosteriorMandibleR_Z ', ' PosteriorMandibleL_X ', ' PosteriorMandibleL_Y ', ' PosteriorMandibleL_Z ', ' PosteriorSuperficialM_X ', ' PosteriorSuperficialM_Y ', ' PosteriorSuperficialM_Z ', ' PosteriorDeepM_X ', ' PosteriorDeepM_Y ', ' PosteriorDeepM_Z ']
# dataset: YeNb_M1F_Superficial
# dataset: Br_CSF_Anterior
# dataset: RyCon_M1F_Deep
# dataset: RyCon_M1F_Anterior
# dataset: Br_M1U_Posterior
# dataset: Br_M1U_Intermediate
# dataset: YeCon_M1U_Intermediate
# dataset: YeCon_M1U_Posterior
# dataset: RyCon_S1F_Anterior
# dataset: YeCon_M1F_Intermediate
# dataset: RyNb_S1U_Posterior
# Epoch 1/20
# 401/401 [==============================] - 15s 36ms/step - loss: 27.4831 - accuracy: 0.2778
# Epoch 2/20
# 401/401 [==============================] - 16s 39ms/step - loss: 25.1806 - accuracy: 0.3056
# Epoch 3/20
# 401/401 [==============================] - 20s 50ms/step - loss: 21.6379 - accuracy: 0.3166
# Epoch 4/20
# 401/401 [==============================] - 18s 45ms/step - loss: 17.3728 - accuracy: 0.3272
# Epoch 5/20
# 401/401 [==============================] - 21s 51ms/step - loss: 14.2134 - accuracy: 0.3446
# Epoch 6/20
# 401/401 [==============================] - 16s 40ms/step - loss: 12.5902 - accuracy: 0.3593
# Epoch 7/20
# 401/401 [==============================] - 18s 45ms/step - loss: 10.7874 - accuracy: 0.3765
# Epoch 8/20
# 401/401 [==============================] - 15s 38ms/step - loss: 9.0650 - accuracy: 0.3977
# Epoch 9/20
# 401/401 [==============================] - 13s 32ms/step - loss: 8.3107 - accuracy: 0.4264
# Epoch 10/20
# 401/401 [==============================] - 15s 38ms/step - loss: 7.0338 - accuracy: 0.4474
# Epoch 11/20
# 401/401 [==============================] - 17s 43ms/step - loss: 5.8336 - accuracy: 0.4831
# Epoch 12/20
# 401/401 [==============================] - 20s 51ms/step - loss: 5.1102 - accuracy: 0.5025
# Epoch 13/20
# 401/401 [==============================] - 18s 46ms/step - loss: 4.6410 - accuracy: 0.5318
# Epoch 14/20
# 401/401 [==============================] - 23s 58ms/step - loss: 3.8572 - accuracy: 0.5617
# Epoch 15/20
# 401/401 [==============================] - 18s 46ms/step - loss: 3.2438 - accuracy: 0.5854
# Epoch 16/20
# 401/401 [==============================] - 17s 43ms/step - loss: 2.7518 - accuracy: 0.6099
# Epoch 17/20
# 401/401 [==============================] - 16s 40ms/step - loss: 2.3936 - accuracy: 0.6340
# Epoch 18/20
# 401/401 [==============================] - 16s 39ms/step - loss: 2.2534 - accuracy: 0.6502
# Epoch 19/20
# 401/401 [==============================] - 22s 54ms/step - loss: 1.9177 - accuracy: 0.6645
# Epoch 20/20
# 401/401 [==============================] - 20s 50ms/step - loss: 1.7281 - accuracy: 0.6780
# 71/71 [==============================] - 1s 8ms/step
# R2: [0.04308893 0.12730018 0.00052746 0.03728839 0.1272298  0.01031664
#  0.0597868  0.09076099 0.04498793 0.06157721 0.09971458 0.0365112 ]
# [' PosteriorMandibleR_X ', ' PosteriorMandibleR_Y ', ' PosteriorMandibleR_Z ', ' PosteriorMandibleL_X ', ' PosteriorMandibleL_Y ', ' PosteriorMandibleL_Z ', ' PosteriorSuperficialM_X ', ' PosteriorSuperficialM_Y ', ' PosteriorSuperficialM_Z ', ' PosteriorDeepM_X ', ' PosteriorDeepM_Y ', ' PosteriorDeepM_Z ']
# dataset: RyNb_S1U_Anterior
# Epoch 1/20
# 401/401 [==============================] - 15s 34ms/step - loss: 62.6551 - accuracy: 0.1520
# Epoch 2/20
# 401/401 [==============================] - 17s 42ms/step - loss: 58.8745 - accuracy: 0.1683
# Epoch 3/20
# 401/401 [==============================] - 16s 39ms/step - loss: 51.9480 - accuracy: 0.1786
# Epoch 4/20
# 401/401 [==============================] - 14s 36ms/step - loss: 42.1066 - accuracy: 0.1920
# Epoch 5/20
# 401/401 [==============================] - 14s 36ms/step - loss: 35.6713 - accuracy: 0.1966
# Epoch 6/20
# 401/401 [==============================] - 15s 38ms/step - loss: 29.9107 - accuracy: 0.2156
# Epoch 7/20
# 401/401 [==============================] - 17s 42ms/step - loss: 26.4819 - accuracy: 0.2248
# Epoch 8/20
# 401/401 [==============================] - 18s 45ms/step - loss: 22.9551 - accuracy: 0.2319
# Epoch 9/20
# 401/401 [==============================] - 17s 43ms/step - loss: 20.3014 - accuracy: 0.2416
# Epoch 10/20
# 401/401 [==============================] - 14s 34ms/step - loss: 16.9538 - accuracy: 0.2592
# Epoch 11/20
# 401/401 [==============================] - 19s 47ms/step - loss: 14.7672 - accuracy: 0.2732
# Epoch 12/20
# 401/401 [==============================] - 26s 65ms/step - loss: 13.2806 - accuracy: 0.2840
# Epoch 13/20
# 401/401 [==============================] - 22s 55ms/step - loss: 11.0807 - accuracy: 0.3065
# Epoch 14/20
# 401/401 [==============================] - 19s 46ms/step - loss: 9.4604 - accuracy: 0.3224
# Epoch 15/20
# 401/401 [==============================] - 20s 51ms/step - loss: 8.1196 - accuracy: 0.3421
# Epoch 16/20
# 401/401 [==============================] - 17s 42ms/step - loss: 7.3461 - accuracy: 0.3567
# Epoch 17/20
# 401/401 [==============================] - 21s 52ms/step - loss: 6.1474 - accuracy: 0.3776
# Epoch 18/20
# 401/401 [==============================] - 22s 55ms/step - loss: 5.5757 - accuracy: 0.3940
# Epoch 19/20
# 401/401 [==============================] - 21s 53ms/step - loss: 5.4298 - accuracy: 0.4085
# Epoch 20/20
# 401/401 [==============================] - 19s 47ms/step - loss: 4.4302 - accuracy: 0.4226
# 71/71 [==============================] - 1s 10ms/step
# R2: [0.01112867 0.11820694 0.00071159 0.00892115 0.11758585 0.00704339
#  0.03793505 0.12947401 0.00112756 0.03607338 0.11979784 0.00564644
#  0.03379935 0.10958412 0.02072893 0.04116887 0.11956791 0.00221619
#  0.04262698 0.10865559 0.02202277]
# [' AnteriorMandibleR_X ', ' AnteriorMandibleR_Y ', ' AnteriorMandibleR_Z ', ' AnteriorMandibleL_X ', ' AnteriorMandibleL_Y ', ' AnteriorMandibleL_Z ', ' AnteriorM_X ', ' AnteriorM_Y ', ' AnteriorM_Z ', ' AnteriorSuperficialR_X ', ' AnteriorSuperficialR_Y ', ' AnteriorSuperficialR_Z ', ' AnteriorSuperficialL_X ', ' AnteriorSuperficialL_Y ', ' AnteriorSuperficialL_Z ', ' AnteriorDeepR_X ', ' AnteriorDeepR_Y ', ' AnteriorDeepR_Z ', ' AnteriorDeepL_X ', ' AnteriorDeepL_Y ', ' AnteriorDeepL_Z ']
# dataset: Br_PFU_Posterior
# dataset: RyNb_M1U_Anterior
# Epoch 1/20
# 401/401 [==============================] - 23s 55ms/step - loss: 37.9764 - accuracy: 0.3591
# Epoch 2/20
# 401/401 [==============================] - 22s 54ms/step - loss: 11.9257 - accuracy: 0.4763
# Epoch 3/20
# 401/401 [==============================] - 19s 47ms/step - loss: 5.8876 - accuracy: 0.5369
# Epoch 4/20
# 401/401 [==============================] - 17s 43ms/step - loss: 3.9953 - accuracy: 0.5910
# Epoch 5/20
# 401/401 [==============================] - 16s 41ms/step - loss: 2.6181 - accuracy: 0.6155
# Epoch 6/20
# 401/401 [==============================] - 23s 56ms/step - loss: 2.4431 - accuracy: 0.6450
# Epoch 7/20
# 401/401 [==============================] - 15s 38ms/step - loss: 1.9334 - accuracy: 0.6694
# Epoch 8/20
# 401/401 [==============================] - 16s 39ms/step - loss: 1.9550 - accuracy: 0.6819
# Epoch 9/20
# 401/401 [==============================] - 18s 46ms/step - loss: 1.3258 - accuracy: 0.6932
# Epoch 10/20
# 401/401 [==============================] - 17s 41ms/step - loss: 1.1258 - accuracy: 0.7088
# Epoch 11/20
# 401/401 [==============================] - 17s 43ms/step - loss: 1.1339 - accuracy: 0.7162
# Epoch 12/20
# 401/401 [==============================] - 21s 53ms/step - loss: 1.0490 - accuracy: 0.7306
# Epoch 13/20
# 401/401 [==============================] - 18s 44ms/step - loss: 0.6656 - accuracy: 0.7367
# Epoch 14/20
# 401/401 [==============================] - 16s 39ms/step - loss: 0.8620 - accuracy: 0.7521
# Epoch 15/20
# 401/401 [==============================] - 18s 44ms/step - loss: 0.7604 - accuracy: 0.7615
# Epoch 16/20
# 401/401 [==============================] - 15s 38ms/step - loss: 0.7728 - accuracy: 0.7624
# Epoch 17/20
# 401/401 [==============================] - 15s 37ms/step - loss: 0.6343 - accuracy: 0.7711
# Epoch 18/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.5513 - accuracy: 0.7770
# Epoch 19/20
# 401/401 [==============================] - 17s 41ms/step - loss: 0.7573 - accuracy: 0.7842
# Epoch 20/20
# 401/401 [==============================] - 19s 48ms/step - loss: 0.4815 - accuracy: 0.7840
# 71/71 [==============================] - 1s 9ms/step
# R2: [0.17993104 0.80752534 0.14684812 0.16088258 0.81459129 0.14956881
#  0.38411354 0.81751768 0.49144804 0.40611099 0.82459233 0.39243888
#  0.34286104 0.77990977 0.43475931 0.41008594 0.82000049 0.38819836
#  0.41212909 0.79015536 0.57963865]
# [' AnteriorMandibleR_X ', ' AnteriorMandibleR_Y ', ' AnteriorMandibleR_Z ', ' AnteriorMandibleL_X ', ' AnteriorMandibleL_Y ', ' AnteriorMandibleL_Z ', ' AnteriorM_X ', ' AnteriorM_Y ', ' AnteriorM_Z ', ' AnteriorSuperficialR_X ', ' AnteriorSuperficialR_Y ', ' AnteriorSuperficialR_Z ', ' AnteriorSuperficialL_X ', ' AnteriorSuperficialL_Y ', ' AnteriorSuperficialL_Z ', ' AnteriorDeepR_X ', ' AnteriorDeepR_Y ', ' AnteriorDeepR_Z ', ' AnteriorDeepL_X ', ' AnteriorDeepL_Y ', ' AnteriorDeepL_Z ']
# dataset: YeCon_M1U_Deep
# dataset: YeNb_M1U_Intermediate
# dataset: Br_M1U_Deep
# dataset: RyCon_M1U_Deep
# dataset: RyNb_M1F_Intermediate
# Epoch 1/20
# 401/401 [==============================] - 20s 46ms/step - loss: 29.8528 - accuracy: 0.4166
# Epoch 2/20
# 401/401 [==============================] - 15s 37ms/step - loss: 24.1345 - accuracy: 0.5119
# Epoch 3/20
# 401/401 [==============================] - 15s 38ms/step - loss: 18.1754 - accuracy: 0.5340
# Epoch 4/20
# 401/401 [==============================] - 17s 43ms/step - loss: 10.8358 - accuracy: 0.5576
# Epoch 5/20
# 401/401 [==============================] - 22s 54ms/step - loss: 6.7392 - accuracy: 0.5829
# Epoch 6/20
# 401/401 [==============================] - 20s 50ms/step - loss: 4.8086 - accuracy: 0.6077
# Epoch 7/20
# 401/401 [==============================] - 18s 46ms/step - loss: 3.6732 - accuracy: 0.6319
# Epoch 8/20
# 401/401 [==============================] - 19s 46ms/step - loss: 2.7622 - accuracy: 0.6597
# Epoch 9/20
# 401/401 [==============================] - 21s 52ms/step - loss: 2.3749 - accuracy: 0.6805
# Epoch 10/20
# 401/401 [==============================] - 21s 51ms/step - loss: 1.9880 - accuracy: 0.6969
# Epoch 11/20
# 401/401 [==============================] - 23s 57ms/step - loss: 1.5960 - accuracy: 0.7162
# Epoch 12/20
# 401/401 [==============================] - 20s 50ms/step - loss: 1.4091 - accuracy: 0.7292
# Epoch 13/20
# 401/401 [==============================] - 16s 41ms/step - loss: 1.1833 - accuracy: 0.7444
# Epoch 14/20
# 401/401 [==============================] - 19s 48ms/step - loss: 1.0922 - accuracy: 0.7564
# Epoch 15/20
# 401/401 [==============================] - 20s 49ms/step - loss: 0.9007 - accuracy: 0.7623
# Epoch 16/20
# 401/401 [==============================] - 24s 61ms/step - loss: 0.8003 - accuracy: 0.7741
# Epoch 17/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.7524 - accuracy: 0.7816
# Epoch 18/20
# 401/401 [==============================] - 17s 43ms/step - loss: 0.6697 - accuracy: 0.7904
# Epoch 19/20
# 401/401 [==============================] - 21s 53ms/step - loss: 0.5896 - accuracy: 0.7985
# Epoch 20/20
# 401/401 [==============================] - 22s 54ms/step - loss: 0.5502 - accuracy: 0.8020
# 71/71 [==============================] - 2s 20ms/step
# R2: [0.61407587 0.73620948 0.29364598 0.66915303 0.76694663 0.58978595
#  0.67930595 0.67142838 0.62718249 0.68660441 0.74387842 0.38839584]
# [' IntermediateSuperficialR_X ', ' IntermediateSuperficialR_Y ', ' IntermediateSuperficialR_Z ', ' IntermediateSuperficialM_X ', ' IntermediateSuperficialM_Y ', ' IntermediateSuperficialM_Z ', ' IntermediateSuperficialL_X ', ' IntermediateSuperficialL_Y ', ' IntermediateSuperficialL_Z ', ' IntermediateDeepM_X ', ' IntermediateDeepM_Y ', ' IntermediateDeepM_Z ']
# dataset: YeNb_S1F_Posterior
# dataset: YeCon_M1F_Deep
# dataset: RyCon_S1F_Posterior
# dataset: RyNb_M1U_Intermediate
# Epoch 1/20
# 401/401 [==============================] - 23s 53ms/step - loss: 20.8875 - accuracy: 0.5367
# Epoch 2/20
# 401/401 [==============================] - 21s 51ms/step - loss: 6.5302 - accuracy: 0.6539
# Epoch 3/20
# 401/401 [==============================] - 22s 56ms/step - loss: 3.3219 - accuracy: 0.6922
# Epoch 4/20
# 401/401 [==============================] - 19s 46ms/step - loss: 2.0198 - accuracy: 0.7301
# Epoch 5/20
# 401/401 [==============================] - 18s 44ms/step - loss: 1.6042 - accuracy: 0.7540
# Epoch 6/20
# 401/401 [==============================] - 16s 40ms/step - loss: 1.2901 - accuracy: 0.7702
# Epoch 7/20
# 401/401 [==============================] - 22s 54ms/step - loss: 1.1248 - accuracy: 0.7850
# Epoch 8/20
# 401/401 [==============================] - 22s 55ms/step - loss: 0.9165 - accuracy: 0.7930
# Epoch 9/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.8167 - accuracy: 0.8062
# Epoch 10/20
# 401/401 [==============================] - 20s 49ms/step - loss: 0.6758 - accuracy: 0.8109
# Epoch 11/20
# 401/401 [==============================] - 20s 49ms/step - loss: 0.8628 - accuracy: 0.8234
# Epoch 12/20
# 401/401 [==============================] - 16s 41ms/step - loss: 0.7442 - accuracy: 0.8342
# Epoch 13/20
# 401/401 [==============================] - 20s 50ms/step - loss: 0.5166 - accuracy: 0.8349
# Epoch 14/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.4979 - accuracy: 0.8398
# Epoch 15/20
# 401/401 [==============================] - 18s 46ms/step - loss: 0.4343 - accuracy: 0.8405
# Epoch 16/20
# 401/401 [==============================] - 19s 49ms/step - loss: 0.4088 - accuracy: 0.8474
# Epoch 17/20
# 401/401 [==============================] - 20s 49ms/step - loss: 0.4102 - accuracy: 0.8531
# Epoch 18/20
# 401/401 [==============================] - 23s 58ms/step - loss: 0.3718 - accuracy: 0.8578
# Epoch 19/20
# 401/401 [==============================] - 24s 61ms/step - loss: 0.3270 - accuracy: 0.8632
# Epoch 20/20
# 401/401 [==============================] - 18s 46ms/step - loss: 0.3148 - accuracy: 0.8603
# 71/71 [==============================] - 1s 10ms/step
# R2: [0.40512124 0.75589201 0.27174313 0.37541195 0.77589219 0.79033283
#  0.4787459  0.70225568 0.79211565 0.37281431 0.71531642 0.62229945]
# [' IntermediateSuperficialR_X ', ' IntermediateSuperficialR_Y ', ' IntermediateSuperficialR_Z ', ' IntermediateSuperficialM_X ', ' IntermediateSuperficialM_Y ', ' IntermediateSuperficialM_Z ', ' IntermediateSuperficialL_X ', ' IntermediateSuperficialL_Y ', ' IntermediateSuperficialL_Z ', ' IntermediateDeepM_X ', ' IntermediateDeepM_Y ', ' IntermediateDeepM_Z ']
# dataset: YeNb_M1F_Intermediate
# dataset: RyCon_M1U_Superficial
# dataset: RyNb_S1F_Anterior
# Epoch 1/20
# 401/401 [==============================] - 20s 46ms/step - loss: 65.2962 - accuracy: 0.0433
# Epoch 2/20
# 401/401 [==============================] - 17s 41ms/step - loss: 65.1449 - accuracy: 0.0542
# Epoch 3/20
# 401/401 [==============================] - 20s 49ms/step - loss: 65.0637 - accuracy: 0.0502
# Epoch 4/20
# 401/401 [==============================] - 16s 40ms/step - loss: 64.9999 - accuracy: 0.0501
# Epoch 5/20
# 401/401 [==============================] - 19s 48ms/step - loss: 64.9249 - accuracy: 0.0510
# Epoch 6/20
# 401/401 [==============================] - 15s 37ms/step - loss: 64.9282 - accuracy: 0.0535
# Epoch 7/20
# 401/401 [==============================] - 14s 35ms/step - loss: 64.8433 - accuracy: 0.0561
# Epoch 8/20
# 401/401 [==============================] - 16s 39ms/step - loss: 64.8068 - accuracy: 0.0603
# Epoch 9/20
# 401/401 [==============================] - 17s 42ms/step - loss: 64.6951 - accuracy: 0.0651
# Epoch 10/20
# 401/401 [==============================] - 16s 39ms/step - loss: 64.5974 - accuracy: 0.0664
# Epoch 11/20
# 401/401 [==============================] - 18s 44ms/step - loss: 64.5188 - accuracy: 0.0663
# Epoch 12/20
# 401/401 [==============================] - 17s 42ms/step - loss: 64.4232 - accuracy: 0.0727
# Epoch 13/20
# 401/401 [==============================] - 14s 36ms/step - loss: 64.2063 - accuracy: 0.0733
# Epoch 14/20
# 401/401 [==============================] - 16s 41ms/step - loss: 63.9255 - accuracy: 0.0747
# Epoch 15/20
# 401/401 [==============================] - 14s 36ms/step - loss: 63.4476 - accuracy: 0.0835
# Epoch 16/20
# 401/401 [==============================] - 21s 52ms/step - loss: 63.1264 - accuracy: 0.0844
# Epoch 17/20
# 401/401 [==============================] - 16s 40ms/step - loss: 62.5641 - accuracy: 0.0884
# Epoch 18/20
# 401/401 [==============================] - 15s 38ms/step - loss: 61.8717 - accuracy: 0.0966
# Epoch 19/20
# 401/401 [==============================] - 17s 42ms/step - loss: 61.0307 - accuracy: 0.0998
# Epoch 20/20
# 401/401 [==============================] - 16s 41ms/step - loss: 60.0036 - accuracy: 0.1023
# 71/71 [==============================] - 1s 11ms/step
# R2: [4.21260699e-03 2.67469531e-03 2.58618146e-03 4.85291788e-03
#  3.05343269e-03 2.79106329e-04 4.21387458e-06 2.81868565e-03
#  1.79787020e-06 2.54102201e-04 2.70048239e-03 5.29374335e-03
#  8.61016893e-06 5.42655778e-03 5.24173876e-04 5.39584138e-04
#  4.08182632e-03 8.14091561e-03 5.66857731e-04 8.26018095e-03
#  7.90636342e-04]
# [' AnteriorMandibleR_X ', ' AnteriorMandibleR_Y ', ' AnteriorMandibleR_Z ', ' AnteriorMandibleL_X ', ' AnteriorMandibleL_Y ', ' AnteriorMandibleL_Z ', ' AnteriorM_X ', ' AnteriorM_Y ', ' AnteriorM_Z ', ' AnteriorSuperficialR_X ', ' AnteriorSuperficialR_Y ', ' AnteriorSuperficialR_Z ', ' AnteriorSuperficialL_X ', ' AnteriorSuperficialL_Y ', ' AnteriorSuperficialL_Z ', ' AnteriorDeepR_X ', ' AnteriorDeepR_Y ', ' AnteriorDeepR_Z ', ' AnteriorDeepL_X ', ' AnteriorDeepL_Y ', ' AnteriorDeepL_Z ']
# dataset: YeCon_S1F_Posterior
# dataset: RyCon_M1F_Intermediate
# dataset: RyNb_S1F_Superficial
# Epoch 1/20
# 401/401 [==============================] - 17s 39ms/step - loss: 48.8499 - accuracy: 0.0922
# Epoch 2/20
# 401/401 [==============================] - 17s 42ms/step - loss: 48.6044 - accuracy: 0.1137
# Epoch 3/20
# 401/401 [==============================] - 15s 37ms/step - loss: 48.5325 - accuracy: 0.1243
# Epoch 4/20
# 401/401 [==============================] - 16s 40ms/step - loss: 48.4496 - accuracy: 0.1231
# Epoch 5/20
# 401/401 [==============================] - 16s 40ms/step - loss: 48.4540 - accuracy: 0.1271
# Epoch 6/20
# 401/401 [==============================] - 16s 40ms/step - loss: 48.4111 - accuracy: 0.1277
# Epoch 7/20
# 401/401 [==============================] - 16s 40ms/step - loss: 48.4007 - accuracy: 0.1266
# Epoch 8/20
# 401/401 [==============================] - 16s 40ms/step - loss: 48.3789 - accuracy: 0.1277
# Epoch 9/20
# 401/401 [==============================] - 16s 39ms/step - loss: 48.3149 - accuracy: 0.1291
# Epoch 10/20
# 401/401 [==============================] - 17s 43ms/step - loss: 48.2779 - accuracy: 0.1319
# Epoch 11/20
# 401/401 [==============================] - 16s 39ms/step - loss: 48.2234 - accuracy: 0.1369
# Epoch 12/20
# 401/401 [==============================] - 17s 42ms/step - loss: 48.1864 - accuracy: 0.1290
# Epoch 13/20
# 401/401 [==============================] - 19s 48ms/step - loss: 48.0575 - accuracy: 0.1323
# Epoch 14/20
# 401/401 [==============================] - 17s 42ms/step - loss: 47.9785 - accuracy: 0.1384
# Epoch 15/20
# 401/401 [==============================] - 17s 42ms/step - loss: 47.8189 - accuracy: 0.1426
# Epoch 16/20
# 401/401 [==============================] - 16s 39ms/step - loss: 47.6574 - accuracy: 0.1446
# Epoch 17/20
# 401/401 [==============================] - 15s 38ms/step - loss: 47.3312 - accuracy: 0.1533
# Epoch 18/20
# 401/401 [==============================] - 15s 38ms/step - loss: 46.9515 - accuracy: 0.1512
# Epoch 19/20
# 401/401 [==============================] - 15s 38ms/step - loss: 46.5488 - accuracy: 0.1560
# Epoch 20/20
# 401/401 [==============================] - 16s 39ms/step - loss: 45.9891 - accuracy: 0.1595
# 71/71 [==============================] - 1s 10ms/step
# R2: [2.50420693e-05 3.31510438e-03 3.49591517e-03 1.62274098e-06
#  6.72140920e-03 2.89078380e-04 2.14670177e-03 4.51097966e-03
#  1.73466713e-03 2.08263092e-03 1.12462978e-02 2.35116696e-06
#  5.28868179e-03 1.70268277e-02 5.62483229e-04 3.36492874e-03
#  5.18715747e-03 3.07983942e-03]
# [' AnteriorSuperficialR_X ', ' AnteriorSuperficialR_Y ', ' AnteriorSuperficialR_Z ', ' AnteriorSuperficialL_X ', ' AnteriorSuperficialL_Y ', ' AnteriorSuperficialL_Z ', ' IntermediateSuperficialR_X ', ' IntermediateSuperficialR_Y ', ' IntermediateSuperficialR_Z ', ' IntermediateSuperficialM_X ', ' IntermediateSuperficialM_Y ', ' IntermediateSuperficialM_Z ', ' IntermediateSuperficialL_X ', ' IntermediateSuperficialL_Y ', ' IntermediateSuperficialL_Z ', ' PosteriorSuperficialM_X ', ' PosteriorSuperficialM_Y ', ' PosteriorSuperficialM_Z ']
# dataset: RyNb_M1F_Anterior
# Epoch 1/20
# 401/401 [==============================] - 16s 37ms/step - loss: 52.7370 - accuracy: 0.2626
# Epoch 2/20
# 401/401 [==============================] - 16s 40ms/step - loss: 45.0250 - accuracy: 0.3486
# Epoch 3/20
# 401/401 [==============================] - 16s 41ms/step - loss: 33.7449 - accuracy: 0.3773
# Epoch 4/20
# 401/401 [==============================] - 16s 40ms/step - loss: 20.8312 - accuracy: 0.4099
# Epoch 5/20
# 401/401 [==============================] - 16s 39ms/step - loss: 12.6064 - accuracy: 0.4279
# Epoch 6/20
# 401/401 [==============================] - 16s 39ms/step - loss: 9.0936 - accuracy: 0.4573
# Epoch 7/20
# 401/401 [==============================] - 16s 40ms/step - loss: 6.7843 - accuracy: 0.4783
# Epoch 8/20
# 401/401 [==============================] - 16s 39ms/step - loss: 5.7333 - accuracy: 0.5058
# Epoch 9/20
# 401/401 [==============================] - 16s 40ms/step - loss: 3.9214 - accuracy: 0.5217
# Epoch 10/20
# 401/401 [==============================] - 16s 40ms/step - loss: 3.2293 - accuracy: 0.5472
# Epoch 11/20
# 401/401 [==============================] - 16s 40ms/step - loss: 2.9334 - accuracy: 0.5748
# Epoch 12/20
# 401/401 [==============================] - 16s 39ms/step - loss: 2.0727 - accuracy: 0.5915
# Epoch 13/20
# 401/401 [==============================] - 16s 39ms/step - loss: 2.1227 - accuracy: 0.6060
# Epoch 14/20
# 401/401 [==============================] - 16s 39ms/step - loss: 1.5119 - accuracy: 0.6246
# Epoch 15/20
# 401/401 [==============================] - 16s 40ms/step - loss: 1.2889 - accuracy: 0.6431
# Epoch 16/20
# 401/401 [==============================] - 16s 39ms/step - loss: 1.3284 - accuracy: 0.6614
# Epoch 17/20
# 401/401 [==============================] - 15s 39ms/step - loss: 1.1562 - accuracy: 0.6709
# Epoch 18/20
# 401/401 [==============================] - 18s 44ms/step - loss: 1.2005 - accuracy: 0.6880
# Epoch 19/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.9854 - accuracy: 0.6918
# Epoch 20/20
# 401/401 [==============================] - 16s 39ms/step - loss: 0.7933 - accuracy: 0.7070
# 71/71 [==============================] - 1s 14ms/step
# R2: [0.25070856 0.72849938 0.0849574  0.22638305 0.73055707 0.10086027
#  0.43153459 0.73927803 0.19049118 0.44028875 0.73756227 0.21200723
#  0.38369631 0.70552589 0.31320382 0.44994666 0.73966599 0.13738197
#  0.45528184 0.72031292 0.3806637 ]
# [' AnteriorMandibleR_X ', ' AnteriorMandibleR_Y ', ' AnteriorMandibleR_Z ', ' AnteriorMandibleL_X ', ' AnteriorMandibleL_Y ', ' AnteriorMandibleL_Z ', ' AnteriorM_X ', ' AnteriorM_Y ', ' AnteriorM_Z ', ' AnteriorSuperficialR_X ', ' AnteriorSuperficialR_Y ', ' AnteriorSuperficialR_Z ', ' AnteriorSuperficialL_X ', ' AnteriorSuperficialL_Y ', ' AnteriorSuperficialL_Z ', ' AnteriorDeepR_X ', ' AnteriorDeepR_Y ', ' AnteriorDeepR_Z ', ' AnteriorDeepL_X ', ' AnteriorDeepL_Y ', ' AnteriorDeepL_Z ']
# dataset: YeNb_M1U_Deep
# dataset: RyCon_M1U_Intermediate
# dataset: YeCon_M1U_Superficial
# dataset: RyCon_M1U_Anterior
# dataset: RyNb_M1F_Posterior
# Epoch 1/20
# 401/401 [==============================] - 16s 38ms/step - loss: 21.9683 - accuracy: 0.4785
# Epoch 2/20
# 401/401 [==============================] - 16s 40ms/step - loss: 17.9981 - accuracy: 0.5437
# Epoch 3/20
# 401/401 [==============================] - 16s 39ms/step - loss: 12.0822 - accuracy: 0.5428
# Epoch 4/20
# 401/401 [==============================] - 16s 39ms/step - loss: 6.9262 - accuracy: 0.5618
# Epoch 5/20
# 401/401 [==============================] - 16s 40ms/step - loss: 4.3260 - accuracy: 0.5965
# Epoch 6/20
# 401/401 [==============================] - 17s 41ms/step - loss: 3.3566 - accuracy: 0.6282
# Epoch 7/20
# 401/401 [==============================] - 16s 40ms/step - loss: 2.6199 - accuracy: 0.6468
# Epoch 8/20
# 401/401 [==============================] - 16s 40ms/step - loss: 1.7367 - accuracy: 0.6772
# Epoch 9/20
# 401/401 [==============================] - 17s 41ms/step - loss: 1.7513 - accuracy: 0.6961
# Epoch 10/20
# 401/401 [==============================] - 16s 40ms/step - loss: 1.1322 - accuracy: 0.7219
# Epoch 11/20
# 401/401 [==============================] - 16s 40ms/step - loss: 1.0050 - accuracy: 0.7402
# Epoch 12/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.7645 - accuracy: 0.7547
# Epoch 13/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.7326 - accuracy: 0.7711
# Epoch 14/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.5512 - accuracy: 0.7853
# Epoch 15/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.5186 - accuracy: 0.8028
# Epoch 16/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.4288 - accuracy: 0.8087
# Epoch 17/20
# 401/401 [==============================] - 17s 41ms/step - loss: 0.3690 - accuracy: 0.8198
# Epoch 18/20
# 401/401 [==============================] - 16s 40ms/step - loss: 0.3962 - accuracy: 0.8267
# Epoch 19/20
# 401/401 [==============================] - 16s 39ms/step - loss: 0.3742 - accuracy: 0.8385
# Epoch 20/20
# 401/401 [==============================] - 16s 41ms/step - loss: 0.2811 - accuracy: 0.8412
# 71/71 [==============================] - 1s 13ms/step
# R2: [0.61173431 0.77656756 0.16228213 0.59586624 0.7746927  0.26652592
#  0.66304909 0.57171912 0.51458147 0.66880741 0.59459748 0.45229513]
# [' PosteriorMandibleR_X ', ' PosteriorMandibleR_Y ', ' PosteriorMandibleR_Z ', ' PosteriorMandibleL_X ', ' PosteriorMandibleL_Y ', ' PosteriorMandibleL_Z ', ' PosteriorSuperficialM_X ', ' PosteriorSuperficialM_Y ', ' PosteriorSuperficialM_Z ', ' PosteriorDeepM_X ', ' PosteriorDeepM_Y ', ' PosteriorDeepM_Z ']
# dataset: RyNb_M1F_Deep
# Epoch 1/20
# 401/401 [==============================] - 18s 40ms/step - loss: 30.5707 - accuracy: 0.3744
# Epoch 2/20
# 401/401 [==============================] - 17s 42ms/step - loss: 25.9247 - accuracy: 0.4546
# Epoch 3/20
# 401/401 [==============================] - 17s 42ms/step - loss: 19.5420 - accuracy: 0.4823
# Epoch 4/20
# 401/401 [==============================] - 17s 44ms/step - loss: 11.8334 - accuracy: 0.5030
# Epoch 5/20
# 401/401 [==============================] - 17s 41ms/step - loss: 7.2976 - accuracy: 0.5284
# Epoch 6/20
# 401/401 [==============================] - 17s 42ms/step - loss: 5.4807 - accuracy: 0.5456
# Epoch 7/20
# 401/401 [==============================] - 17s 43ms/step - loss: 3.8362 - accuracy: 0.5706
# Epoch 8/20
# 401/401 [==============================] - 17s 42ms/step - loss: 3.3174 - accuracy: 0.6011
# Epoch 9/20
# 401/401 [==============================] - 17s 43ms/step - loss: 2.4845 - accuracy: 0.6265
# Epoch 10/20
# 401/401 [==============================] - 17s 43ms/step - loss: 2.0329 - accuracy: 0.6445
# Epoch 11/20
# 401/401 [==============================] - 17s 43ms/step - loss: 1.6619 - accuracy: 0.6684
# Epoch 12/20
# 401/401 [==============================] - 19s 47ms/step - loss: 1.3071 - accuracy: 0.6865
# Epoch 13/20
# 401/401 [==============================] - 17s 42ms/step - loss: 1.2004 - accuracy: 0.7090
# Epoch 14/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.9915 - accuracy: 0.7217
# Epoch 15/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.8491 - accuracy: 0.7384
# Epoch 16/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.8852 - accuracy: 0.7488
# Epoch 17/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.6973 - accuracy: 0.7614
# Epoch 18/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.5994 - accuracy: 0.7660
# Epoch 19/20
# 401/401 [==============================] - 17s 43ms/step - loss: 0.5634 - accuracy: 0.7842
# Epoch 20/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.5176 - accuracy: 0.7896
# 71/71 [==============================] - 1s 9ms/step
# R2: [0.60217427 0.77410591 0.26094267 0.6084654  0.76432133 0.43430163
#  0.63481425 0.73231087 0.34529085 0.67092018 0.62171299 0.39665954]
# [' AnteriorDeepR_X ', ' AnteriorDeepR_Y ', ' AnteriorDeepR_Z ', ' AnteriorDeepL_X ', ' AnteriorDeepL_Y ', ' AnteriorDeepL_Z ', ' IntermediateDeepM_X ', ' IntermediateDeepM_Y ', ' IntermediateDeepM_Z ', ' PosteriorDeepM_X ', ' PosteriorDeepM_Y ', ' PosteriorDeepM_Z ']
# dataset: RyCon_S1U_Anterior
# dataset: YeNb_M1U_Superficial
# dataset: YeNb_M1U_Posterior
# dataset: Br_CSF_Deep
# dataset: YeNb_M1F_Deep
# dataset: YeNb_S1U_Superficial
# dataset: YeCon_S1U_Superficial
# dataset: RyNb_M1F_Superficial
# Epoch 1/20
# 401/401 [==============================] - 19s 44ms/step - loss: 36.6048 - accuracy: 0.3109
# Epoch 2/20
# 401/401 [==============================] - 17s 42ms/step - loss: 30.4191 - accuracy: 0.4070
# Epoch 3/20
# 401/401 [==============================] - 17s 43ms/step - loss: 23.3788 - accuracy: 0.4523
# Epoch 4/20
# 401/401 [==============================] - 17s 43ms/step - loss: 15.1145 - accuracy: 0.4801
# Epoch 5/20
# 401/401 [==============================] - 18s 44ms/step - loss: 8.8113 - accuracy: 0.5085
# Epoch 6/20
# 401/401 [==============================] - 17s 42ms/step - loss: 6.2727 - accuracy: 0.5351
# Epoch 7/20
# 401/401 [==============================] - 17s 42ms/step - loss: 5.3355 - accuracy: 0.5665
# Epoch 8/20
# 401/401 [==============================] - 17s 43ms/step - loss: 4.3380 - accuracy: 0.5828
# Epoch 9/20
# 401/401 [==============================] - 17s 43ms/step - loss: 3.3180 - accuracy: 0.6036
# Epoch 10/20
# 401/401 [==============================] - 17s 43ms/step - loss: 2.9061 - accuracy: 0.6293
# Epoch 11/20
# 401/401 [==============================] - 17s 43ms/step - loss: 2.3189 - accuracy: 0.6385
# Epoch 12/20
# 401/401 [==============================] - 17s 43ms/step - loss: 2.1824 - accuracy: 0.6600
# Epoch 13/20
# 401/401 [==============================] - 17s 42ms/step - loss: 1.7263 - accuracy: 0.6822
# Epoch 14/20
# 401/401 [==============================] - 17s 42ms/step - loss: 1.6036 - accuracy: 0.6971
# Epoch 15/20
# 401/401 [==============================] - 18s 45ms/step - loss: 1.3208 - accuracy: 0.7129
# Epoch 16/20
# 401/401 [==============================] - 17s 42ms/step - loss: 1.2706 - accuracy: 0.7246
# Epoch 17/20
# 401/401 [==============================] - 17s 42ms/step - loss: 1.1292 - accuracy: 0.7314
# Epoch 18/20
# 401/401 [==============================] - 17s 43ms/step - loss: 1.0578 - accuracy: 0.7411
# Epoch 19/20
# 401/401 [==============================] - 17s 43ms/step - loss: 0.8916 - accuracy: 0.7544
# Epoch 20/20
# 401/401 [==============================] - 18s 44ms/step - loss: 0.8680 - accuracy: 0.7591
# 71/71 [==============================] - 1s 10ms/step
# R2: [0.64233821 0.76819806 0.34240039 0.60521528 0.73306162 0.34922135
#  0.59983708 0.72916694 0.25258951 0.6722391  0.76964621 0.55751012
#  0.67695741 0.67349286 0.62810528 0.66829344 0.57141559 0.45663739]
# [' AnteriorSuperficialR_X ', ' AnteriorSuperficialR_Y ', ' AnteriorSuperficialR_Z ', ' AnteriorSuperficialL_X ', ' AnteriorSuperficialL_Y ', ' AnteriorSuperficialL_Z ', ' IntermediateSuperficialR_X ', ' IntermediateSuperficialR_Y ', ' IntermediateSuperficialR_Z ', ' IntermediateSuperficialM_X ', ' IntermediateSuperficialM_Y ', ' IntermediateSuperficialM_Z ', ' IntermediateSuperficialL_X ', ' IntermediateSuperficialL_Y ', ' IntermediateSuperficialL_Z ', ' PosteriorSuperficialM_X ', ' PosteriorSuperficialM_Y ', ' PosteriorSuperficialM_Z ']
# dataset: RyNb_M1U_Deep
# Epoch 1/20
# 401/401 [==============================] - 19s 45ms/step - loss: 21.2145 - accuracy: 0.4918
# Epoch 2/20
# 401/401 [==============================] - 19s 48ms/step - loss: 5.6041 - accuracy: 0.5916
# Epoch 3/20
# 401/401 [==============================] - 19s 48ms/step - loss: 3.4489 - accuracy: 0.6424
# Epoch 4/20
# 401/401 [==============================] - 19s 46ms/step - loss: 2.2694 - accuracy: 0.6880
# Epoch 5/20
# 401/401 [==============================] - 19s 47ms/step - loss: 2.0140 - accuracy: 0.7190
# Epoch 6/20
# 401/401 [==============================] - 19s 47ms/step - loss: 1.4066 - accuracy: 0.7406
# Epoch 7/20
# 401/401 [==============================] - 18s 45ms/step - loss: 1.1569 - accuracy: 0.7609
# Epoch 8/20
# 401/401 [==============================] - 19s 48ms/step - loss: 1.1623 - accuracy: 0.7770
# Epoch 9/20
# 401/401 [==============================] - 19s 47ms/step - loss: 0.7286 - accuracy: 0.7822
# Epoch 10/20
# 401/401 [==============================] - 19s 47ms/step - loss: 0.8217 - accuracy: 0.7960
# Epoch 11/20
# 401/401 [==============================] - 19s 47ms/step - loss: 0.6977 - accuracy: 0.8094
# Epoch 12/20
# 401/401 [==============================] - 19s 46ms/step - loss: 0.5623 - accuracy: 0.8116
# Epoch 13/20
# 401/401 [==============================] - 19s 46ms/step - loss: 0.5624 - accuracy: 0.8170
# Epoch 14/20
# 401/401 [==============================] - 19s 47ms/step - loss: 0.5294 - accuracy: 0.8251
# Epoch 15/20
# 401/401 [==============================] - 20s 50ms/step - loss: 0.4365 - accuracy: 0.8275
# Epoch 16/20
# 401/401 [==============================] - 18s 44ms/step - loss: 0.5477 - accuracy: 0.8373
# Epoch 17/20
# 401/401 [==============================] - 17s 42ms/step - loss: 0.4130 - accuracy: 0.8422
# Epoch 18/20
# 401/401 [==============================] - 18s 44ms/step - loss: 0.3878 - accuracy: 0.8448
# Epoch 19/20
# 401/401 [==============================] - 19s 46ms/step - loss: 0.3166 - accuracy: 0.8493
# Epoch 20/20
# 401/401 [==============================] - 18s 45ms/step - loss: 0.3388 - accuracy: 0.8551
# 71/71 [==============================] - 1s 11ms/step
# R2: [0.62874357 0.87773966 0.41529874 0.61571261 0.8557556  0.62759735
#  0.64361955 0.8260845  0.5879557  0.73736056 0.73615693 0.71483228]
# [' AnteriorDeepR_X ', ' AnteriorDeepR_Y ', ' AnteriorDeepR_Z ', ' AnteriorDeepL_X ', ' AnteriorDeepL_Y ', ' AnteriorDeepL_Z ', ' IntermediateDeepM_X ', ' IntermediateDeepM_Y ', ' IntermediateDeepM_Z ', ' PosteriorDeepM_X ', ' PosteriorDeepM_Y ', ' PosteriorDeepM_Z ']
# dataset: RyCon_S1U_Superficial
# dataset: RyCon_M1U_Posterior
